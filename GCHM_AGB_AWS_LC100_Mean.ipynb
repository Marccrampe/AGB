# %% [markdown]
# <a href="https://colab.research.google.com/github/Marccrampe/AGB/blob/main/GCHM_AGB_AWS_LC100_Mean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r /content/drive/MyDrive/GCHM_AGB_AWS/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 126.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 96.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 40.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# ...

# %%
import boto3

# ⬇️ Remplace par tes vraies clés (ne les partage pas publiquement !)
aws_access_key = "AKIAT5W7P33GLHRBMLPM"
aws_secret_key = "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"

s3 = boto3.client(
    "s3",
    aws_access_key_id=aws_access_key,
    aws_secret_access_key=aws_secret_key,
    region_name="eu-west-1"
)
import ee
import google.auth
from google.colab import auth
from google.cloud import storage

# Authentification
auth.authenticate_user()

# Charger les credentials
credentials, project = google.auth.default()

# Configurer Google Cloud Storage
client = storage.Client(credentials=credentials, project=project)

# %%
# !python3 /content/drive/MyDrive/GCHM_AGB_AWS/gchm/geo_inferences.py \
    --service_account_key "/content/drive/MyDrive/GCHM_AGB_AWS/gchm/canopy-height-model-00-2bedb8675644.json" \
    --bucket_name "canopy-marc" \
    --geojson_path "AOI/lande.json" \
    --date_array "2019-06-01" "2025-01-15"\
    --aoi_name "Landes_France_LC100" \
    --batch_size 64 \
    --model_dir "/content/drive/MyDrive/GCHM_AGB_AWS/trained_models/GLOBAL_GEDI_2019_2020" \
    --num_models 5 \
    --finetune_strategy "FT_Lm_SRCB" \
# Out:
# ✅ Earth Engine initialized successfully with service account: open-atlas-ee-api@canopy-height-model-00.iam.gserviceaccount.com
# 📢 Projet used for Earth Engine : canopy-height-model-00
# ESA mask successfully loaded.
# [2019-06-01] DW mask generated.
# [2025-01-15] DW mask generated.
# 📤 Exporting Landes_France_LC100_2019-06-01 to gs://gchm-predictions-test/DATASET_GEE_TIF/Landes_France_LC100_2019-06-01...
# 📤 Exporting Landes_France_LC100_2019-06-01 to gs://gchm-predictions-test/DATASET_GEE_TIF/Landes_France_LC100_2019-06-01...
# 📤 Exporting Landes_France_LC100_2019-06-01 to gs://gchm-predictions-test/DATASET_GEE_TIF/Landes_France_LC100_2019-06-01...
# 📤 Exporting Landes_France_LC100_2019-06-01 to gs://gchm-predictions-test/DATASET_GEE_TIF/Landes_France_LC100_2019-06-01...
# 📤 Exporting Landes_France_LC100_2019-06-01 to gs://gchm-predictions-test/DATASET_GEE_TIF/Landes_France_LC100_2019-06-01...
# ...
